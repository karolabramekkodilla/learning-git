# %%
def count (a,b)
    return a+b
# Out:
#   Cell In[1], line 1
#     def count (a,b)
#                    ^
# SyntaxError: expected ':'

# %%
def count (a,b):
    return a+b

# %%
1
1
1
2
2
3
4
5
count(10,10)
count(1,1)
# Out:
# 2
