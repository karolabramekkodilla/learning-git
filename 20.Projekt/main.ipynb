# %%
# data manipulation
import numpy as np
import pandas as pd
import datetime as dt
import time
from math import sqrt
from tqdm import tqdm
import holidays

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# feature selection
from sklearn.feature_selection import RFECV

# pipeline
from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, TransformerMixin

# models
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# optimization and hyperparameters
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit

# model evaluation
from sklearn.metrics import mean_squared_error
from sklearn.metrics import make_scorer

# interpretowalność modelu
import shap
shap.initjs()

# zapisanie modelu
import joblib

# settings
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221(e,t,n){"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},l=Symbol.for("react.portal"),u=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:l,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=u.T,n=o.p;try{if(u.T=null,o.p=2,e)return e()}finally{u.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return u.H.useFormState(e,t,n)},t.useFormStatus=function(){return u.H.useHostTransitionStatus()},t.version="19.2.4"},247(e,t,n){"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function l(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function u(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&null!== ...

# %%
dataframe = pd.read_csv('bikerides_day.csv')
dataframe['Date'] = pd.to_datetime(dataframe['Date'])
dataframe
# Out:
#            Date  Volume  Rain  Temp
# 0    2016-11-17   933.0   9.0   2.1
# 1    2016-11-18  1197.0   6.7   3.9
# 2    2016-11-19   243.0   5.4   2.0
# 3    2016-11-20   234.0   3.9   2.8
# 4    2016-11-21  2148.0   7.3   2.8
# ...         ...     ...   ...   ...
# 1268 2020-05-16  2484.0   0.0   6.6
# 1269 2020-05-17  1509.0   0.0   9.1
# 1270 2020-05-18  5775.0   0.0   9.3
# 1271 2020-05-19  6741.0   0.0   9.7
# 1272 2020-05-20  1647.0   0.0  10.8
#
# [1273 rows x 4 columns]

# %%
dataframe.isnull().mean()*100
# Out:
# Date      0.0
# Volume    0.0
# Rain      0.0
# Temp      0.0
# dtype: float64

# %%
dataframe.loc[dataframe.duplicated(subset='Date', keep=False), :]
# Out:
# Empty DataFrame
# Columns: [Date, Volume, Rain, Temp]
# Index: []

# %%
(dataframe['Date'] == dataframe['Date'].sort_values()).all()
# Out:
# True

# %%
pd.date_range(start=dataframe['Date'].min(), end=dataframe['Date'].max()).difference(dataframe['Date'])
# Out:
# DatetimeIndex(['2017-10-16', '2019-01-14', '2019-06-07', '2019-06-08',
#                '2019-06-09', '2019-06-10', '2019-08-14', '2019-08-15'],
#               dtype='datetime64[ns]', freq=None)

# %%
dataframe.loc[dataframe['Date']=='2017-10-16',:]
# Out:
# Empty DataFrame
# Columns: [Date, Volume, Rain, Temp]
# Index: []

# %%
dataframe.loc[dataframe['Date']=='2017-10-15',:]
# Out:
#           Date  Volume  Rain  Temp
# 332 2017-10-15   843.0   0.0   9.6

# %%
dataframe.describe()
# Out:
#                                 Date       Volume         Rain         Temp
# count                           1273  1273.000000  1273.000000  1273.000000
# mean   2018-08-17 15:16:15.648075264  2609.344855     1.945640     6.783975
# min              2016-11-17 00:00:00    63.000000     0.000000   -11.400000
# 25%              2017-10-01 00:00:00  1185.000000     0.000000     0.700000
# 50%              2018-08-16 00:00:00  2073.000000     0.000000     5.500000
# 75%              2019-07-05 00:00:00  3801.000000     1.400000    13.400000
# max              2020-05-20 00:00:00  8679.000000    39.500000    25.900000
# std                              NaN  1968.623825     4.505151     7.726084

# %%
for variable in dataframe.select_dtypes(include=np.number).columns:
    fig = plt.figure(figsize=(16, 2))
    fig.suptitle(variable, fontsize=12)
    plt.subplot(121)
    sns.distplot(dataframe[variable], kde=True, rug=False)
    plt.title('Histogram')
    plt.subplot(122)
    plt.boxplot(dataframe[variable])
    plt.title('Wykres pudełkowy')
    plt.show()

# %%
plt.figure(figsize=(16, 8), dpi=100)
plt.plot(dataframe['Date'], dataframe['Volume'],
         color='tab:red', label='Volume for every day')
plt.plot(dataframe['Date'], dataframe['Volume'].rolling(7).mean(),
         color='tab:blue', linewidth=4, label='7-dniowa średnia krocząca')
plt.title('Osoby wypożyczające rowery na pewnej trasie w Oslo 2016-2020')
plt.xlabel('Date')
plt.ylabel('Liczba')
plt.xlim([dataframe['Date'].min(), dataframe['Date'].max()])
plt.ylim([0, dataframe['Volume'].max()*1.025])
plt.legend(loc='upper right')
plt.show()

# %%
full_years = dataframe.loc[(dataframe['Date'] >= '2017-01-01') & (dataframe['Date'] < '2020-01-01')].copy()
full_years['year'] = [d.year for d in full_years['Date']]
full_years['month'] = [d.strftime('%b') for d in full_years['Date']]
full_years['weekday'] = [d.strftime('%A') for d in full_years['Date']]
full_years
# Out:
#            Date  Volume  Rain  Temp  year month    weekday
# 45   2017-01-01   183.0   0.0   1.1  2017   Jan     Sunday
# 46   2017-01-02  1752.0   0.0  -2.8  2017   Jan     Monday
# 47   2017-01-03  1956.0   0.0  -2.5  2017   Jan    Tuesday
# 48   2017-01-04  1854.0   0.0  -3.1  2017   Jan  Wednesday
# 49   2017-01-05  1113.0   0.0 -10.1  2017   Jan   Thursday
# ...         ...     ...   ...   ...   ...   ...        ...
# 1127 2019-12-27   342.0   0.0  -4.9  2019   Dec     Friday
# 1128 2019-12-28    63.0   0.0  -1.2  2019   Dec   Saturday
# 1129 2019-12-29   126.0   5.9   4.4  2019   Dec     Sunday
# 1130 2019-12-30   558.0   0.0   5.5  2019   Dec     Monday
# 1131 2019-12-31   315.0   0.0   1.1  2019   Dec    Tuesday
#
# [1087 rows x 7 columns]

# %%
full_years_monthly = full_years.groupby(['year', 'month'])[['Volume']].mean()
full_years_monthly.reset_index(inplace=True)
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
          "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

full_years_monthly['month'] = pd.Categorical(full_years_monthly['month'], categories=months, ordered=True)
full_years_monthly.sort_values(by=['year', 'month'], inplace=True)
display(full_years_monthly.head(3))
display(full_years_monthly.tail(3))
# Out:
#    year month       Volume
# 4  2017   Jan  1202.225806
# 3  2017   Feb   980.250000
# 7  2017   Mar  1703.419355
#     year month       Volume
# 34  2019   Oct  3204.967742
# 33  2019   Nov  1852.500000
# 26  2019   Dec  1035.580645

# %%
plt.figure(figsize=(16, 8), dpi=100)
for year in full_years['year'].unique():
    plt.plot(full_years_monthly.loc[full_years_monthly['year']==year, 'month'],
             full_years_monthly.loc[full_years_monthly['year']==year, 'Volume'], label=year)
    print(year)
plt.legend(loc='upper left')
plt.xlim(['Jan', 'Dec'])
plt.show()
# Out:
# 2017
# 2018
# 2019

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 5), dpi=80)
sns.boxplot(x='year', y='Volume', data=full_years, ax=axes[0]).set(
    xlabel='Rok',
    ylabel='Liczba'
)

axes[0].set_title('Box plot dla lat (trend)')
sns.boxplot(x='month', y='Volume', data=full_years, ax=axes[1]).set(
    xlabel='Miesiąc',
    ylabel='Liczba'
)

axes[1].set_title('Box plot dla miesiący (sezonowość)')
sns.boxplot(x='weekday', y='Volume', data=full_years, ax=axes[2]).set(
    xlabel='Dzień tygodnia',
    ylabel='Liczba'
)

axes[2].set_title('Box plot dla dni tygodnia (sezonowość)')
axes[2].set_xticklabels(axes[2].get_xticklabels(), rotation=30)
plt.show()

# %%
holidays_Norway = holidays.NO()
def get_holiday(row):
    holidays = holidays_Norway.get(row['Date'])
    if holidays == None:
        return np.NaN

    # Søndag, czyli niedziela jest traktowana jako święto - usuwamy to święto
    elif holidays != 'Søndag':

        # Usunięcie niedzieli nakładającej się z innymi świętami
        if 'Søndag' in holidays:
            holidays = holidays.replace('Søndag', '')
            holidays = holidays.replace(',', '')
            holidays = holidays.lstrip().rstrip()
            return holidays
        else:
            return holidays
    else:
        return np.NaN
full_years['Holiday'] = full_years.apply(get_holiday, axis=1)
print('Unikalne święta:')
print(full_years['Holiday'].value_counts())
full_years
# Out:
# Unikalne święta:
# Holiday
# Første nyttårsdag        3
# Skjærtorsdag             3
# Langfredag               3
# Første påskedag          3
# Andre påskedag           3
# Arbeidernes dag          3
# Grunnlovsdag             3
# Kristi himmelfartsdag    3
# Første juledag           3
# Andre juledag            3
# Første pinsedag          2
# Andre pinsedag           2
# Name: count, dtype: int64
#            Date  Volume  Rain  Temp  year month    weekday            Holiday
# 45   2017-01-01   183.0   0.0   1.1  2017   Jan     Sunday  Første nyttårsdag
# 46   2017-01-02  1752.0   0.0  -2.8  2017   Jan     Monday                NaN
# 47   2017-01-03  1956.0   0.0  -2.5  2017   Jan    Tuesday                NaN
# 48   2017-01-04  1854.0   0.0  -3.1  2017   Jan  Wednesday                NaN
# 49   2017-01-05  1113.0   0.0 -10.1  2017   Jan   Thursday                NaN
# ...         ...     ...   ...   ...   ...   ...        ...                ...
# 1127 2019-12-27   342.0   0.0  -4.9  2019   Dec     Friday                NaN
# 1128 2019-12-28    63.0   0.0  -1.2  2019   Dec   Saturday                NaN
# 1129 2019-12-29   126.0   5.9   4.4  2019   Dec     Sunday                NaN
# 1130 2019-12-30   558.0   0.0   5.5  2019   Dec     Monday                NaN
# 1131 2019-12-31   315.0   0.0   1.1  2019   Dec    Tuesday                NaN
#
# [1087 rows x 8 columns]

# %%
for unique_holiday in full_years['Holiday'].dropna().unique():

    # Filtrowanie miesięcy, w których to święto wystąpiło, usunięcie innych świąt w tym samym okresie
    month_holiday = full_years.loc[full_years['Holiday']==unique_holiday, 'month'].unique()
    selected_holiday = full_years.loc[((full_years['month'].isin(month_holiday))&\
                                       (full_years['Holiday'].isin([np.NaN, unique_holiday]))), :].copy()
    selected_holiday['Holiday'].fillna('Brak święta', inplace=True)

    # Wizualizacja wykresu plotowego
    plt.figure(figsize=(8, 1))
    sns.boxplot(x=selected_holiday['Holiday'], y=selected_holiday['Volume'],
                palette="Blues", order=['Brak święta', unique_holiday])
    plt.title(f'Święto: {unique_holiday}, Miesiące: {month_holiday}')
    plt.show()

# %%
full_years.loc[~full_years['Holiday'].isnull(), 'Holiday'] = 1
full_years.fillna(0, inplace=True)
full_years
# Out:
#            Date  Volume  Rain  Temp  year month    weekday  Holiday
# 45   2017-01-01   183.0   0.0   1.1  2017   Jan     Sunday        1
# 46   2017-01-02  1752.0   0.0  -2.8  2017   Jan     Monday        0
# 47   2017-01-03  1956.0   0.0  -2.5  2017   Jan    Tuesday        0
# 48   2017-01-04  1854.0   0.0  -3.1  2017   Jan  Wednesday        0
# 49   2017-01-05  1113.0   0.0 -10.1  2017   Jan   Thursday        0
# ...         ...     ...   ...   ...   ...   ...        ...      ...
# 1127 2019-12-27   342.0   0.0  -4.9  2019   Dec     Friday        0
# 1128 2019-12-28    63.0   0.0  -1.2  2019   Dec   Saturday        0
# 1129 2019-12-29   126.0   5.9   4.4  2019   Dec     Sunday        0
# 1130 2019-12-30   558.0   0.0   5.5  2019   Dec     Monday        0
# 1131 2019-12-31   315.0   0.0   1.1  2019   Dec    Tuesday        0
#
# [1087 rows x 8 columns]

# %%
plt.figure(figsize=(16, 7))
sns.boxplot(x=full_years['Holiday'], y=full_years['Volume'], palette="Blues")
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 5), dpi=80)
pd.plotting.lag_plot(dataframe['Volume'], lag=1, ax=axes[0], alpha=0.3)
pd.plotting.lag_plot(dataframe['Volume'], lag=7, ax=axes[1], alpha=0.3)
pd.plotting.lag_plot(dataframe['Volume'], lag=365, ax=axes[2], alpha=0.3)
plt.show()

# %%
sns.pairplot(full_years[['Volume', 'Rain', 'Temp', 'weekday']], hue='weekday', kind='scatter', plot_kws={'alpha':0.25})
plt.show()

# %%
dataframe
# Out:
#            Date  Volume  Rain  Temp
# 0    2016-11-17   933.0   9.0   2.1
# 1    2016-11-18  1197.0   6.7   3.9
# 2    2016-11-19   243.0   5.4   2.0
# 3    2016-11-20   234.0   3.9   2.8
# 4    2016-11-21  2148.0   7.3   2.8
# ...         ...     ...   ...   ...
# 1268 2020-05-16  2484.0   0.0   6.6
# 1269 2020-05-17  1509.0   0.0   9.1
# 1270 2020-05-18  5775.0   0.0   9.3
# 1271 2020-05-19  6741.0   0.0   9.7
# 1272 2020-05-20  1647.0   0.0  10.8
#
# [1273 rows x 4 columns]

# %%
class AddMissingDates(BaseEstimator, TransformerMixin):
    def __init__(self, date_column):
        self.date_column = date_column
        pass
    def fit(self, X, y = None ):
        return self
    def transform(self, X, y = None ):
        X_transformed = X.copy()

        # Ustawienie kolumny z czasem jako indeksu
        X_transformed = X_transformed.set_index(self.date_column)
        X_transformed.index = pd.to_datetime(X_transformed.index)

        # Dodanie brakujących
        new_idx = pd.date_range(X_transformed.index.min(), X_transformed.index.max())
        X_transformed = X_transformed.reindex(new_idx)
        return X_transformed

# %%
steps = [
    ('add_missing_dates', AddMissingDates(date_column='Date'))
]
data_preparation_pipeline = Pipeline(steps = steps)
dataframe_prepared = data_preparation_pipeline.fit_transform(dataframe)
dataframe_prepared
# Out:
#             Volume  Rain  Temp
# 2016-11-17   933.0   9.0   2.1
# 2016-11-18  1197.0   6.7   3.9
# 2016-11-19   243.0   5.4   2.0
# 2016-11-20   234.0   3.9   2.8
# 2016-11-21  2148.0   7.3   2.8
# ...            ...   ...   ...
# 2020-05-16  2484.0   0.0   6.6
# 2020-05-17  1509.0   0.0   9.1
# 2020-05-18  5775.0   0.0   9.3
# 2020-05-19  6741.0   0.0   9.7
# 2020-05-20  1647.0   0.0  10.8
#
# [1281 rows x 3 columns]

# %%
dataframe_prepared.loc[dataframe_prepared.index=='2017-10-16',:]
# Out:
#             Volume  Rain  Temp
# 2017-10-16     NaN   NaN   NaN

# %%
class FillMissings(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    def fit(self, X, y = None ):
        return self

    def transform(self, X, y = None ):
        X_transformed = X.copy()

        # Uzupełnienie brakujących wartości dla liczby wypożyczonych rowerów
        X_transformed.loc[X_transformed['Volume'].isnull(), 'Volume'] = X_transformed['Volume'].shift(7)

        # Uzupełnienie brakujących wartości dla zmiennych pogodowych
        X_transformed.loc[X_transformed['Rain'].isnull(), 'Rain'] = X_transformed['Rain'].shift(1)
        X_transformed.loc[X_transformed['Temp'].isnull(), 'Temp'] = X_transformed['Temp'].shift(1)

        return X_transformed

# %%
steps = [
    ('add_missing_dates', AddMissingDates(date_column='Date')),
    ('fill_missing_values', FillMissings())
]
data_preparation_pipeline = Pipeline(steps = steps)
dataframe_prepared = data_preparation_pipeline.fit_transform(dataframe)
dataframe_prepared
# Out:
#             Volume  Rain  Temp
# 2016-11-17   933.0   9.0   2.1
# 2016-11-18  1197.0   6.7   3.9
# 2016-11-19   243.0   5.4   2.0
# 2016-11-20   234.0   3.9   2.8
# 2016-11-21  2148.0   7.3   2.8
# ...            ...   ...   ...
# 2020-05-16  2484.0   0.0   6.6
# 2020-05-17  1509.0   0.0   9.1
# 2020-05-18  5775.0   0.0   9.3
# 2020-05-19  6741.0   0.0   9.7
# 2020-05-20  1647.0   0.0  10.8
#
# [1281 rows x 3 columns]

# %%
dataframe_prepared.loc[dataframe_prepared.index=='2017-10-16',:]
# Out:
#             Volume  Rain  Temp
# 2017-10-16  4947.0   0.0   9.6

# %%
class FeatureEngineeringTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    def fit( self, X, y = None ):
        return self
    def transform( self, X, y = None ):
        def encode_time(X, col, max_val):
            X[col + '_sin'] = np.sin(2 * np.pi * X[col]/max_val)
            X[col + '_cos'] = np.cos(2 * np.pi * X[col]/max_val)
            X.drop(col, axis='columns', inplace=True)
            return X
        def get_holiday(row):
            holidays = holidays_Norway.get(row['Date'])
            if holidays == None:
                return 0

            # Søndag, czyli niedziela jest traktowana jako święto - usuwamy to święto
            elif holidays != 'Søndag':

                # Usunięcie niedzieli nakładającej się z innymi świętami
                if 'Søndag' in holidays:
                    holidays = holidays.replace('Søndag', '')
                    holidays = holidays.replace(',', '')
                    holidays = holidays.lstrip().rstrip()
                    return 1
                else:
                    return 1
            else:
                return 0
        X_transformed = X.copy()

        # Zmienne z przeszłości - możemy stosować wartości maksymalnie sprzed tygodnia
        # Dlatego najświeższą wartością z przeszłości dla wypożyczonych rowerów będzie wartość sprzed tygodnia
        X_transformed['Volume_lag_7W'] = X_transformed['Volume'].shift(7)

        # Opóźnione wartości
        for lag in range(1, 15):
            X_transformed[f'Volume_lag_{lag+7}W'] = X_transformed['Volume_lag_7W'].shift(lag)

        # Kroczące statystyki
        for window in [7, 14]:
            X_transformed[f'Volume_window_{window}_mean'] = X_transformed['Volume_lag_7W'].rolling(window=window).mean()
            X_transformed[f'Volume_window_{window}_std'] = X_transformed['Volume_lag_7W'].rolling(window=window).std()
            X_transformed[f'Volume_window_{window}_min'] = X_transformed['Volume_lag_7W'].rolling(window=window).min()
            X_transformed[f'Volume_window_{window}_max'] = X_transformed['Volume_lag_7W'].rolling(window=window).max()

        # Dzień w roku - sezonowość
        X_transformed['day_of_year'] = X_transformed.index.dayofyear
        X_transformed = encode_time(X_transformed, 'day_of_year', 366)

        # Dzień w tygodniu - sezonowość
        X_transformed['weekday'] = X_transformed.index.weekday
        X_transformed = encode_time(X_transformed, 'weekday', 7)

        # Rok - należy rozróżnić wartości z 2017 roku, wtedy średnio było mniej wypożyczeń
        X_transformed['year'] = X_transformed.index.year

        # Dodanie święta
        X_transformed['Date'] = X_transformed.index
        X_transformed['Holiday'] = X_transformed.apply(get_holiday, axis=1)
        X_transformed.drop(['Date'], axis=1, inplace=True)

        # Usunięcie wierszy z brakującymi danymi
        X_transformed.dropna(inplace=True)
        return X_transformed

# %%
steps = [
    ('add_missing_dates', AddMissingDates(date_column='Date')),
    ('fill_missing_values', FillMissings()),
    ('feature_engineering', FeatureEngineeringTransformer())
]

data_preparation_pipeline = Pipeline(steps = steps)
dataframe_prepared = data_preparation_pipeline.fit_transform(dataframe)
dataframe_prepared
# Out:
#             Volume  Rain  Temp  Volume_lag_7W  Volume_lag_8W  Volume_lag_9W  \
# 2016-12-08  1743.0  10.3   5.7         1620.0         1908.0         1884.0
# 2016-12-09  1608.0   0.0   3.4         1464.0         1620.0         1908.0
# 2016-12-10   261.0   0.3   2.1          213.0         1464.0         1620.0
# 2016-12-11   354.0   3.4   0.5          246.0          213.0         1464.0
# 2016-12-12  1941.0   0.0  -1.1         2079.0          246.0          213.0
# ...            ...   ...   ...            ...            ...            ...
# 2020-05-16  2484.0   0.0   6.6         3681.0         4884.0         5649.0
# 2020-05-17  1509.0   0.0   9.1         1320.0         3681.0         4884.0
# 2020-05-18  5775.0   0.0   9.3         5304.0         1320.0         3681.0
# 2020-05-19  6741.0   0.0   9.7         4881.0         5304.0         1320.0
# 2020-05-20  1647.0   0.0  10.8         5808.0         4881.0         5304.0
#
#             Volume_lag_10W  Volume_lag_11W  Volume_lag_12W  Volume_lag_13W  \
# 2016-12-08          2175.0           396.0           384.0          1638.0
# 2016-12-09          1884.0          2175.0           396.0           384.0
# 2016-12-10          1908.0          1884.0          2175.0           396.0
# 2016-12-11          1620.0          1908.0          1884.0          2175.0
# 2016-12-12          1464.0          1620.0          1908.0          1884.0
# ...                    ...             ...             ...             ...
# 2020-05-16          6126.0          5853.0          4962.0          3072.0
# 2020-05-17          5649.0          6126.0          5853.0          4962.0
# 2020-05-18          4884.0          5649.0          6126.0          5853.0
# 2020-05-19          3681.0          4884.0          5649.0          6126.0
# 2020-05-20          1320.0          3681.0          4884.0          5649.0
#
#             ...  Volume_window_14_mean  Volume_window_14_std  \
# 2016-12-08  ...            1407.642857            761.568483
# 2016-12-09  ...            1426.714286            759.227282
# 2016-12-10  ...            1424.571429            762.858865
# 2016-12-11  ...            1425.428571            761.423638
# 2016-12-12  ...            1420.500000            756.594775
# ...         ...                    ...                   ...
# 2020-05-16  ...            4090.500000           1326.470200
# 2020-05-17  ...            3925.928571           1517.910429
# 2020-05-18  ...            4157.571429           1457.674160
# 2020-05-19  ...            4271.571429           1446.550417
# 2020-05-20  ...            4337.785714           1496.931075
#
#             Volume_window_14_min  Volume_window_14_max  day_of_year_sin  \
# 2016-12-08                 234.0                2175.0        -0.384665
# 2016-12-09                 234.0                2175.0        -0.368763
# 2016-12-10                 213.0                2175.0        -0.352752
# 2016-12-11                 213.0                2175.0        -0.336637
# 2016-12-12                 213.0                2175.0        -0.320423
# ...                          ...                   ...              ...
# 2020-05-16                2049.0                6126.0         0.710135
# 2020-05-17                1320.0                6126.0         0.697944
# 2020-05-18                1320.0                6126.0         0.685548
# 2020-05-19                1320.0                6126.0         0.672949
# 2020-05-20                1320.0                6126.0         0.660152
#
#             day_of_year_cos  weekday_sin  weekday_cos  year  Holiday
# 2016-12-08         0.923056     0.433884    -0.900969  2016        0
# 2016-12-09         0.929523    -0.433884    -0.900969  2016        0
# 2016-12-10         0.935717    -0.974928    -0.222521  2016        0
# 2016-12-11         0.941634    -0.781831     0.623490  2016        0
# 2016-12-12         0.947274     0.000000     1.000000  2016        0
# ...                     ...          ...          ...   ...      ...
# 2020-05-16        -0.704066    -0.974928    -0.222521  2020        0
# 2020-05-17        -0.716152    -0.781831     0.623490  2020        1
# 2020-05-18        -0.728028     0.000000     1.000000  2020        0
# 2020-05-19        -0.739689     0.781831     0.623490  2020        0
# 2020-05-20        -0.751132     0.974928    -0.222521  2020        0
#
# [1256 rows x 32 columns]

# %%
X = dataframe_prepared.drop(['Volume'], axis=1)
y = dataframe_prepared['Volume']

# %%
first_test_date = dt.datetime.strptime('2020-01-01', '%Y-%m-%d')
X_train, y_train = X[X.index<first_test_date].copy(), y[y.index<first_test_date].copy()
X_test, y_test = X[X.index>=first_test_date].copy(), y[y.index>=first_test_date].copy()

# %%
importances = RandomForestRegressor(n_estimators=1000, max_depth=20, n_jobs=-1).fit(X_train, y_train).feature_importances_
features = pd.concat([pd.DataFrame(X_train.columns, columns=['feat']),
                      pd.DataFrame(importances, columns=['importance'])
                     ], axis=1).sort_values(by='importance', ascending=False)
features = features[features['importance']>0.0075]
features.loc[features['feat'].str.contains('Volume_lag_'), 'Busket'] = 'lag'
features.loc[features['feat'].str.contains('mean'), 'Busket'] = 'mean'
features.loc[features['feat'].str.contains('std'), 'Busket'] = 'std'
features.loc[features['feat'].str.contains('min'), 'Busket'] = 'min'
features.loc[features['feat'].str.contains('max'), 'Busket'] = 'max'
display(features)
features = features[(~features.duplicated(subset='Busket', keep='first'))|(features['Busket'].isnull())]
features = list(features['feat'].values)
print(f'Liczba zmiennych: {len(features)}')
print(f'Zmienne: {features}')
# Out:
#                     feat  importance Busket
# 2          Volume_lag_7W    0.638205    lag
# 9         Volume_lag_14W    0.063576    lag
# 1                   Temp    0.030943    NaN
# 25       day_of_year_sin    0.025074    NaN
# 26       day_of_year_cos    0.024605    NaN
# 20   Volume_window_7_max    0.022507    max
# 24  Volume_window_14_max    0.018276    max
# 30               Holiday    0.017327    NaN
# 16        Volume_lag_21W    0.015942    lag
# 22  Volume_window_14_std    0.013702    std
# 18   Volume_window_7_std    0.012545    std
# 3          Volume_lag_8W    0.009992    lag
# 0                   Rain    0.008582    NaN
# 23  Volume_window_14_min    0.008501    min
# 27           weekday_sin    0.008323    NaN
# 7         Volume_lag_12W    0.007891    lag
# Liczba zmiennych: 10
# Zmienne: ['Volume_lag_7W', 'Temp', 'day_of_year_sin', 'day_of_year_cos', 'Volume_window_7_max', 'Holiday', 'Volume_window_14_std', 'Rain', 'Volume_window_14_min', 'weekday_sin']

# %%
X_train = X_train[features]
X_test = X_test[features]

# %%
prediction_baseline = y.copy()
prediction_baseline = np.round((prediction_baseline.shift(367) + prediction_baseline.shift(7)) / 2)
prediction_baseline.dropna(inplace=True)
prediction_baseline = prediction_baseline[prediction_baseline.index>=first_test_date]
prediction_baseline
# Out:
# 2020-01-01     144.0
# 2020-01-02     219.0
# 2020-01-03     278.0
# 2020-01-04      87.0
# 2020-01-05     134.0
#                ...
# 2020-05-16    3192.0
# 2020-05-17    1744.0
# 2020-05-18    6190.0
# 2020-05-19    6130.0
# 2020-05-20    6510.0
# Name: Volume, Length: 141, dtype: float64

# %%
def plot_prediction_vs_true(yhat_list, yhat_names, ytest):
    plt.figure(figsize=(16, 8), dpi=100)
    plt.plot(ytest, color='black', label='True', linewidth=3)
    for yhat, yname in zip(yhat_list, yhat_names):
        plt.plot(yhat, label=f'Prediction - {yname}')
    plt.xlim([ytest.index.min(), ytest.index.max()])
    plt.legend(loc='upper left')
    plt.show()

plot_prediction_vs_true(yhat_list=[prediction_baseline],
                        yhat_names=['Baseline'],
                        ytest=y_test)

# %%
def Cost(y_true, y_pred):
        def apply_cost(x):
            if x < 0:
                x = np.abs(x)*10
            return x
        y_pred = np.round(y_pred)
        cost = y_pred - y_true
        cost = cost.apply(apply_cost)
        return np.sum(cost)

# %%
def model_evaluation(yhat, ytest):
    def fit_scatter_plot(yhat, ytest):
        xmin = ytest.min()
        xmax = ytest.max()
        plt.scatter(x = yhat, y = ytest, alpha=0.25)
        x_line = np.linspace(xmin, xmax, 10)
        y_line = x_line
        plt.plot(x_line, y_line, 'r--')
        plt.xlabel('Predykcja')
        plt.ylabel('Wartość Prawdziwa')
        plt.title(f'Wykres predykcji względem wartości prawdziwych - Test set')
    def plot_of_residuals(yhat, ytest):
        errors = yhat - ytest
        plt.scatter(x = ytest, y = errors, alpha=0.25)
        plt.axhline(0, color="r", linestyle="--")
        plt.xlabel('Wartość Prawdziwa')
        plt.ylabel('Reszta')
        plt.title(f'Wykres reszt - Test set')
    def hist_of_residuals(yhat, ytest):
        errors = yhat - ytest
        plt.hist(errors, bins = 100)
        plt.axvline(errors.mean(), color='k', linestyle='dashed', linewidth=1)
        plt.title(f'Histogram reszt - Test set')
    fig = plt.figure(figsize = (18, 6))
    fig.subplots_adjust(hspace=0.2, wspace=0.2)
    ax = fig.add_subplot(1, 3, 1)
    fit_scatter_plot(yhat, ytest)
    ax = fig.add_subplot(1, 3, 2)
    plot_of_residuals(yhat, ytest)
    ax = fig.add_subplot(1, 3, 3)
    hist_of_residuals(yhat, ytest)
    plt.show()

    print(f'RMSE Test: {sqrt(mean_squared_error(ytest, yhat))}')
    print(f'Pomniejszony zysk: {Cost(ytest, yhat)}')

# %%
model_evaluation(yhat=prediction_baseline, ytest=y_test)
# Out:
# RMSE Test: 1127.9512337932003
# Pomniejszony zysk: 884447.0

# %%
cost_scorer = make_scorer(Cost, greater_is_better=False)

# %%
tree = DecisionTreeRegressor(random_state=2022)
params = {'max_depth': [2, 3, 5, 7, 10],
          'min_samples_leaf': [2, 3, 5, 7, 10]}
tree_gridsearch = GridSearchCV(tree,
                               params,
                               scoring=cost_scorer,
                               cv=TimeSeriesSplit(n_splits=5),
                               verbose=10,
                               n_jobs=1)
tree_gridsearch.fit(X_train, y_train)
print('\nNajlepsze hiperparametry:', tree_gridsearch.best_params_)
tree_model = tree_gridsearch.best_estimator_
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5; 1/25] START max_depth=2, min_samples_leaf=2............................
# [CV 1/5; 1/25] END max_depth=2, min_samples_leaf=2;, score=-747343.000 total time=   0.0s
# [CV 2/5; 1/25] START max_depth=2, min_samples_leaf=2............................
# [CV 2/5; 1/25] END max_depth=2, min_samples_leaf=2;, score=-1300574.000 total time=   0.0s
# [CV 3/5; 1/25] START max_depth=2, min_samples_leaf=2............................
# [CV 3/5; 1/25] END max_depth=2, min_samples_leaf=2;, score=-998327.000 total time=   0.0s
# [CV 4/5; 1/25] START max_depth=2, min_samples_leaf=2............................
# [CV 4/5; 1/25] END max_depth=2, min_samples_leaf=2;, score=-1070427.000 total time=   0.0s
# [CV 5/5; 1/25] START max_depth=2, min_samples_leaf=2............................
# [CV 5/5; 1/25] END max_depth=2, min_samples_leaf=2;, score=-825273.000 total time=   0.0s
# [CV 1/5; 2/25] START max_depth=2, min_samples_leaf=3............................
# [CV 1/5; 2/25] END max_depth=2, min_samples_leaf=3;, score=-747343.000 total time=   0.0s
# [CV 2/5; 2/25] START max_depth=2, min_samples_leaf=3............................
# [CV 2/5; 2/25] END max_depth=2, min_samples_leaf=3;, score=-1300574.000 total time=   0.0s
# [CV 3/5; 2/25] START max_depth=2, min_samples_leaf=3............................
# [CV 3/5; 2/25] END max_depth=2, min_samples_leaf=3;, score=-998327.000 total time=   0.0s
# [CV 4/5; 2/25] START max_depth=2, min_samples_leaf=3............................
# [CV 4/5; 2/25] END max_depth=2, min_samples_leaf=3;, score=-1070427.000 total time=   0.0s
# [CV 5/5; 2/25] START max_depth=2, min_samples_leaf=3............................
# [CV 5/5; 2/25] END max_depth=2, min_samples_leaf=3;, score=-825273.000 total time=   0.0s
# [CV 1/5; 3/25] START max_depth=2, min_samples_leaf=5............................
# [CV 1/5; 3/25] END max_depth=2, min_samples_leaf=5;, score=-747343.000 total time=   0.0s
# [CV 2/5; 3/25] START max_depth=2, min_samples_leaf=5............................
# [CV 2/5; 3/25] END max_depth=2, min_samples_leaf=5;, score=-1300574.000 total time=   0.0s
# [CV 3/5; 3/25] START max_depth=2, min_samples_leaf=5............................
# [CV 3/5; 3/25] END max_depth=2, min_samples_leaf=5;, score=-998327.000 total time=   0.0s
# [CV 4/5; 3/25] START max_depth=2, min_samples_leaf=5............................
# [CV 4/5; 3/25] END max_depth=2, min_samples_leaf=5;, score=-1070427.000 total time=   0.0s
# [CV 5/5; 3/25] START max_depth=2, min_samples_leaf=5............................
# [CV 5/5; 3/25] END max_depth=2, min_samples_leaf=5;, score=-825273.000 total time=   0.0s
# [CV 1/5; 4/25] START max_depth=2, min_samples_leaf=7............................
# [CV 1/5; 4/25] END max_depth=2, min_samples_leaf=7;, score=-747343.000 total time=   0.0s
# [CV 2/5; 4/25] START max_depth=2, min_samples_leaf=7............................
# [CV 2/5; 4/25] END max_depth=2, min_samples_leaf=7;, score=-1300574.000 total time=   0.0s
# [CV 3/5; 4/25] START max_depth=2, min_samples_leaf=7............................
# [CV 3/5; 4/25] END max_depth=2, min_samples_leaf=7;, score=-998327.000 total time=   0.0s
# [CV 4/5; 4/25] START max_depth=2, min_samples_leaf=7............................
# [CV 4/5; 4/25] END max_depth=2, min_samples_leaf=7;, score=-1070427.000 total time=   0.0s
# [CV 5/5; 4/25] START max_depth=2, min_samples_leaf=7............................
# [CV 5/5; 4/25] END max_depth=2, min_samples_leaf=7;, score=-825273.000 total time=   0.0s
# [CV 1/5; 5/25] START max_depth=2, min_samples_leaf=10...........................
# [CV 1/5; 5/25] END max_depth=2, min_samples_leaf=10;, score=-747343.000 total time=   0.0s
# [CV 2/5; 5/25] START max_depth=2, min_samples_leaf=10...........................
# [CV 2/5; 5/25] END max_depth=2, min_samples_leaf=10;, score=-1300574.000 total time=   0.0s
# [CV 3/5; 5/25] START max_depth=2, min_samples_leaf=10...........................
# [CV 3/5; 5/25] END max_depth=2, min_samples_leaf=10;, score=-998327.000 total time=   0.0s
# [CV 4/5; 5/25] START max_depth=2, min_samples_leaf=10...........................
# [CV 4/5; 5/25] END max_depth=2, min_samples_leaf=10;, score=-1070427.000 total time=   0.0s
# [CV 5/5; 5/25] START max_depth=2, min_samples_leaf=10...........................
# [CV 5/5; 5/25] END max_depth=2, min_samples_leaf=10;, score=-825273.000 total time=   0.0s
# [CV 1/5; 6/25] START max_depth=3, min_samples_leaf=2............................
# [CV 1/5; 6/25] END max_depth=3, min_samples_leaf=2;, score=-658857.000 total time=   0.0s
# [CV 2/5; 6/25] START max_depth=3, min_samples_leaf=2............................
# [CV 2/5; 6/25] END max_depth=3, min_samples_leaf=2;, score=-1039591.000 total time=   0.0s
# [CV 3/5; 6/25] START max_depth=3, min_samples_leaf=2............................
# [CV 3/5; 6/25] END max_depth=3, min_samples_leaf=2;, score=-970326.000 total time=   0.0s
# [CV 4/5; 6/25] START max_depth=3, min_samples_leaf=2............................
# [CV 4/5; 6/25] END max_depth=3, min_samples_leaf=2;, score=-1117483.000 total time=   0.0s
# [CV 5/5; 6/25] START max_depth=3, min_samples_leaf=2............................
# [CV 5/5; 6/25] END max_depth=3, min_samples_leaf=2;, score=-734143.000 total time=   0.0s
# [CV 1/5; 7/25] START max_depth=3, min_samples_leaf=3............................
# [CV 1/5; 7/25] END max_depth=3, min_samples_leaf=3;, score=-657447.000 total time=   0.0s
# [CV 2/5; 7/25] START max_depth=3, min_samples_leaf=3............................
# [CV 2/5; 7/25] END max_depth=3, min_samples_leaf=3;, score=-1108019.000 total time=   0.0s
# [CV 3/5; 7/25] START max_depth=3, min_samples_leaf=3............................
# [CV 3/5; 7/25] END max_depth=3, min_samples_leaf=3;, score=-970326.000 total time=   0.0s
# [CV 4/5; 7/25] START max_depth=3, min_samples_leaf=3............................
# [CV 4/5; 7/25] END max_depth=3, min_samples_leaf=3;, score=-1117483.000 total time=   0.0s
# [CV 5/5; 7/25] START max_depth=3, min_samples_leaf=3............................
# [CV 5/5; 7/25] END max_depth=3, min_samples_leaf=3;, score=-734143.000 total time=   0.0s
# [CV 1/5; 8/25] START max_depth=3, min_samples_leaf=5............................
# [CV 1/5; 8/25] END max_depth=3, min_samples_leaf=5;, score=-748388.000 total time=   0.0s
# [CV 2/5; 8/25] START max_depth=3, min_samples_leaf=5............................
# [CV 2/5; 8/25] END max_depth=3, min_samples_leaf=5;, score=-1108383.000 total time=   0.0s
# [CV 3/5; 8/25] START max_depth=3, min_samples_leaf=5............................
# [CV 3/5; 8/25] END max_depth=3, min_samples_leaf=5;, score=-970326.000 total time=   0.0s
# [CV 4/5; 8/25] START max_depth=3, min_samples_leaf=5............................
# [CV 4/5; 8/25] END max_depth=3, min_samples_leaf=5;, score=-1117483.000 total time=   0.0s
# [CV 5/5; 8/25] START max_depth=3, min_samples_leaf=5............................
# [CV 5/5; 8/25] END max_depth=3, min_samples_leaf=5;, score=-734143.000 total time=   0.0s
# [CV 1/5; 9/25] START max_depth=3, min_samples_leaf=7............................
# [CV 1/5; 9/25] END max_depth=3, min_samples_leaf=7;, score=-875037.000 total time=   0.0s
# [CV 2/5; 9/25] START max_depth=3, min_samples_leaf=7............................
# [CV 2/5; 9/25] END max_depth=3, min_samples_leaf=7;, score=-1084607.000 total time=   0.0s
# [CV 3/5; 9/25] START max_depth=3, min_samples_leaf=7............................
# [CV 3/5; 9/25] END max_depth=3, min_samples_leaf=7;, score=-970326.000 total time=   0.0s
# [CV 4/5; 9/25] START max_depth=3, min_samples_leaf=7............................
# [CV 4/5; 9/25] END max_depth=3, min_samples_leaf=7;, score=-1117483.000 total time=   0.0s
# [CV 5/5; 9/25] START max_depth=3, min_samples_leaf=7............................
# [CV 5/5; 9/25] END max_depth=3, min_samples_leaf=7;, score=-734143.000 total time=   0.0s
# [CV 1/5; 10/25] START max_depth=3, min_samples_leaf=10..........................
# [CV 1/5; 10/25] END max_depth=3, min_samples_leaf=10;, score=-889763.000 total time=   0.0s
# [CV 2/5; 10/25] START max_depth=3, min_samples_leaf=10..........................
# [CV 2/5; 10/25] END max_depth=3, min_samples_leaf=10;, score=-1091756.000 total time=   0.0s
# [CV 3/5; 10/25] START max_depth=3, min_samples_leaf=10..........................
# [CV 3/5; 10/25] END max_depth=3, min_samples_leaf=10;, score=-970326.000 total time=   0.0s
# [CV 4/5; 10/25] START max_depth=3, min_samples_leaf=10..........................
# [CV 4/5; 10/25] END max_depth=3, min_samples_leaf=10;, score=-1117483.000 total time=   0.0s
# [CV 5/5; 10/25] START max_depth=3, min_samples_leaf=10..........................
# [CV 5/5; 10/25] END max_depth=3, min_samples_leaf=10;, score=-702707.000 total time=   0.0s
# [CV 1/5; 11/25] START max_depth=5, min_samples_leaf=2...........................
# [CV 1/5; 11/25] END max_depth=5, min_samples_leaf=2;, score=-838515.000 total time=   0.0s
# [CV 2/5; 11/25] START max_depth=5, min_samples_leaf=2...........................
# [CV 2/5; 11/25] END max_depth=5, min_samples_leaf=2;, score=-926382.000 total time=   0.0s
# [CV 3/5; 11/25] START max_depth=5, min_samples_leaf=2...........................
# [CV 3/5; 11/25] END max_depth=5, min_samples_leaf=2;, score=-714252.000 total time=   0.0s
# [CV 4/5; 11/25] START max_depth=5, min_samples_leaf=2...........................
# [CV 4/5; 11/25] END max_depth=5, min_samples_leaf=2;, score=-897330.000 total time=   0.0s
# [CV 5/5; 11/25] START max_depth=5, min_samples_leaf=2...........................
# [CV 5/5; 11/25] END max_depth=5, min_samples_leaf=2;, score=-720491.000 total time=   0.0s
# [CV 1/5; 12/25] START max_depth=5, min_samples_leaf=3...........................
# [CV 1/5; 12/25] END max_depth=5, min_samples_leaf=3;, score=-788317.000 total time=   0.0s
# [CV 2/5; 12/25] START max_depth=5, min_samples_leaf=3...........................
# [CV 2/5; 12/25] END max_depth=5, min_samples_leaf=3;, score=-972614.000 total time=   0.0s
# [CV 3/5; 12/25] START max_depth=5, min_samples_leaf=3...........................
# [CV 3/5; 12/25] END max_depth=5, min_samples_leaf=3;, score=-725912.000 total time=   0.0s
# [CV 4/5; 12/25] START max_depth=5, min_samples_leaf=3...........................
# [CV 4/5; 12/25] END max_depth=5, min_samples_leaf=3;, score=-862574.000 total time=   0.0s
# [CV 5/5; 12/25] START max_depth=5, min_samples_leaf=3...........................
# [CV 5/5; 12/25] END max_depth=5, min_samples_leaf=3;, score=-719247.000 total time=   0.0s
# [CV 1/5; 13/25] START max_depth=5, min_samples_leaf=5...........................
# [CV 1/5; 13/25] END max_depth=5, min_samples_leaf=5;, score=-858853.000 total time=   0.0s
# [CV 2/5; 13/25] START max_depth=5, min_samples_leaf=5...........................
# [CV 2/5; 13/25] END max_depth=5, min_samples_leaf=5;, score=-951215.000 total time=   0.0s
# [CV 3/5; 13/25] START max_depth=5, min_samples_leaf=5...........................
# [CV 3/5; 13/25] END max_depth=5, min_samples_leaf=5;, score=-850311.000 total time=   0.0s
# [CV 4/5; 13/25] START max_depth=5, min_samples_leaf=5...........................
# [CV 4/5; 13/25] END max_depth=5, min_samples_leaf=5;, score=-976537.000 total time=   0.0s
# [CV 5/5; 13/25] START max_depth=5, min_samples_leaf=5...........................
# [CV 5/5; 13/25] END max_depth=5, min_samples_leaf=5;, score=-706966.000 total time=   0.0s
# [CV 1/5; 14/25] START max_depth=5, min_samples_leaf=7...........................
# [CV 1/5; 14/25] END max_depth=5, min_samples_leaf=7;, score=-885037.000 total time=   0.0s
# [CV 2/5; 14/25] START max_depth=5, min_samples_leaf=7...........................
# [CV 2/5; 14/25] END max_depth=5, min_samples_leaf=7;, score=-975086.000 total time=   0.0s
# [CV 3/5; 14/25] START max_depth=5, min_samples_leaf=7...........................
# [CV 3/5; 14/25] END max_depth=5, min_samples_leaf=7;, score=-844389.000 total time=   0.0s
# [CV 4/5; 14/25] START max_depth=5, min_samples_leaf=7...........................
# [CV 4/5; 14/25] END max_depth=5, min_samples_leaf=7;, score=-1019321.000 total time=   0.0s
# [CV 5/5; 14/25] START max_depth=5, min_samples_leaf=7...........................
# [CV 5/5; 14/25] END max_depth=5, min_samples_leaf=7;, score=-712059.000 total time=   0.0s
# [CV 1/5; 15/25] START max_depth=5, min_samples_leaf=10..........................
# [CV 1/5; 15/25] END max_depth=5, min_samples_leaf=10;, score=-882750.000 total time=   0.0s
# [CV 2/5; 15/25] START max_depth=5, min_samples_leaf=10..........................
# [CV 2/5; 15/25] END max_depth=5, min_samples_leaf=10;, score=-984230.000 total time=   0.0s
# [CV 3/5; 15/25] START max_depth=5, min_samples_leaf=10..........................
# [CV 3/5; 15/25] END max_depth=5, min_samples_leaf=10;, score=-955765.000 total time=   0.0s
# [CV 4/5; 15/25] START max_depth=5, min_samples_leaf=10..........................
# [CV 4/5; 15/25] END max_depth=5, min_samples_leaf=10;, score=-936623.000 total time=   0.0s
# [CV 5/5; 15/25] START max_depth=5, min_samples_leaf=10..........................
# [CV 5/5; 15/25] END max_depth=5, min_samples_leaf=10;, score=-789497.000 total time=   0.0s
# [CV 1/5; 16/25] START max_depth=7, min_samples_leaf=2...........................
# [CV 1/5; 16/25] END max_depth=7, min_samples_leaf=2;, score=-719784.000 total time=   0.0s
# [CV 2/5; 16/25] START max_depth=7, min_samples_leaf=2...........................
# [CV 2/5; 16/25] END max_depth=7, min_samples_leaf=2;, score=-908346.000 total time=   0.0s
# [CV 3/5; 16/25] START max_depth=7, min_samples_leaf=2...........................
# [CV 3/5; 16/25] END max_depth=7, min_samples_leaf=2;, score=-961740.000 total time=   0.0s
# [CV 4/5; 16/25] START max_depth=7, min_samples_leaf=2...........................
# [CV 4/5; 16/25] END max_depth=7, min_samples_leaf=2;, score=-943445.000 total time=   0.0s
# [CV 5/5; 16/25] START max_depth=7, min_samples_leaf=2...........................
# [CV 5/5; 16/25] END max_depth=7, min_samples_leaf=2;, score=-730755.000 total time=   0.0s
# [CV 1/5; 17/25] START max_depth=7, min_samples_leaf=3...........................
# [CV 1/5; 17/25] END max_depth=7, min_samples_leaf=3;, score=-891837.000 total time=   0.0s
# [CV 2/5; 17/25] START max_depth=7, min_samples_leaf=3...........................
# [CV 2/5; 17/25] END max_depth=7, min_samples_leaf=3;, score=-934133.000 total time=   0.0s
# [CV 3/5; 17/25] START max_depth=7, min_samples_leaf=3...........................
# [CV 3/5; 17/25] END max_depth=7, min_samples_leaf=3;, score=-792791.000 total time=   0.0s
# [CV 4/5; 17/25] START max_depth=7, min_samples_leaf=3...........................
# [CV 4/5; 17/25] END max_depth=7, min_samples_leaf=3;, score=-937415.000 total time=   0.0s
# [CV 5/5; 17/25] START max_depth=7, min_samples_leaf=3...........................
# [CV 5/5; 17/25] END max_depth=7, min_samples_leaf=3;, score=-789264.000 total time=   0.0s
# [CV 1/5; 18/25] START max_depth=7, min_samples_leaf=5...........................
# [CV 1/5; 18/25] END max_depth=7, min_samples_leaf=5;, score=-813664.000 total time=   0.0s
# [CV 2/5; 18/25] START max_depth=7, min_samples_leaf=5...........................
# [CV 2/5; 18/25] END max_depth=7, min_samples_leaf=5;, score=-882511.000 total time=   0.0s
# [CV 3/5; 18/25] START max_depth=7, min_samples_leaf=5...........................
# [CV 3/5; 18/25] END max_depth=7, min_samples_leaf=5;, score=-902892.000 total time=   0.0s
# [CV 4/5; 18/25] START max_depth=7, min_samples_leaf=5...........................
# [CV 4/5; 18/25] END max_depth=7, min_samples_leaf=5;, score=-988299.000 total time=   0.0s
# [CV 5/5; 18/25] START max_depth=7, min_samples_leaf=5...........................
# [CV 5/5; 18/25] END max_depth=7, min_samples_leaf=5;, score=-736825.000 total time=   0.0s
# [CV 1/5; 19/25] START max_depth=7, min_samples_leaf=7...........................
# [CV 1/5; 19/25] END max_depth=7, min_samples_leaf=7;, score=-883351.000 total time=   0.0s
# [CV 2/5; 19/25] START max_depth=7, min_samples_leaf=7...........................
# [CV 2/5; 19/25] END max_depth=7, min_samples_leaf=7;, score=-963567.000 total time=   0.0s
# [CV 3/5; 19/25] START max_depth=7, min_samples_leaf=7...........................
# [CV 3/5; 19/25] END max_depth=7, min_samples_leaf=7;, score=-903362.000 total time=   0.0s
# [CV 4/5; 19/25] START max_depth=7, min_samples_leaf=7...........................
# [CV 4/5; 19/25] END max_depth=7, min_samples_leaf=7;, score=-991854.000 total time=   0.0s
# [CV 5/5; 19/25] START max_depth=7, min_samples_leaf=7...........................
# [CV 5/5; 19/25] END max_depth=7, min_samples_leaf=7;, score=-709649.000 total time=   0.0s
# [CV 1/5; 20/25] START max_depth=7, min_samples_leaf=10..........................
# [CV 1/5; 20/25] END max_depth=7, min_samples_leaf=10;, score=-824195.000 total time=   0.0s
# [CV 2/5; 20/25] START max_depth=7, min_samples_leaf=10..........................
# [CV 2/5; 20/25] END max_depth=7, min_samples_leaf=10;, score=-991412.000 total time=   0.0s
# [CV 3/5; 20/25] START max_depth=7, min_samples_leaf=10..........................
# [CV 3/5; 20/25] END max_depth=7, min_samples_leaf=10;, score=-1009254.000 total time=   0.0s
# [CV 4/5; 20/25] START max_depth=7, min_samples_leaf=10..........................
# [CV 4/5; 20/25] END max_depth=7, min_samples_leaf=10;, score=-868186.000 total time=   0.0s
# [CV 5/5; 20/25] START max_depth=7, min_samples_leaf=10..........................
# [CV 5/5; 20/25] END max_depth=7, min_samples_leaf=10;, score=-828929.000 total time=   0.0s
# [CV 1/5; 21/25] START max_depth=10, min_samples_leaf=2..........................
# [CV 1/5; 21/25] END max_depth=10, min_samples_leaf=2;, score=-757145.000 total time=   0.0s
# [CV 2/5; 21/25] START max_depth=10, min_samples_leaf=2..........................
# [CV 2/5; 21/25] END max_depth=10, min_samples_leaf=2;, score=-790671.000 total time=   0.0s
# [CV 3/5; 21/25] START max_depth=10, min_samples_leaf=2..........................
# [CV 3/5; 21/25] END max_depth=10, min_samples_leaf=2;, score=-1116337.000 total time=   0.0s
# [CV 4/5; 21/25] START max_depth=10, min_samples_leaf=2..........................
# [CV 4/5; 21/25] END max_depth=10, min_samples_leaf=2;, score=-855283.000 total time=   0.0s
# [CV 5/5; 21/25] START max_depth=10, min_samples_leaf=2..........................
# [CV 5/5; 21/25] END max_depth=10, min_samples_leaf=2;, score=-734875.000 total time=   0.0s
# [CV 1/5; 22/25] START max_depth=10, min_samples_leaf=3..........................
# [CV 1/5; 22/25] END max_depth=10, min_samples_leaf=3;, score=-888061.000 total time=   0.0s
# [CV 2/5; 22/25] START max_depth=10, min_samples_leaf=3..........................
# [CV 2/5; 22/25] END max_depth=10, min_samples_leaf=3;, score=-820554.000 total time=   0.0s
# [CV 3/5; 22/25] START max_depth=10, min_samples_leaf=3..........................
# [CV 3/5; 22/25] END max_depth=10, min_samples_leaf=3;, score=-958107.000 total time=   0.0s
# [CV 4/5; 22/25] START max_depth=10, min_samples_leaf=3..........................
# [CV 4/5; 22/25] END max_depth=10, min_samples_leaf=3;, score=-978765.000 total time=   0.0s
# [CV 5/5; 22/25] START max_depth=10, min_samples_leaf=3..........................
# [CV 5/5; 22/25] END max_depth=10, min_samples_leaf=3;, score=-818269.000 total time=   0.0s
# [CV 1/5; 23/25] START max_depth=10, min_samples_leaf=5..........................
# [CV 1/5; 23/25] END max_depth=10, min_samples_leaf=5;, score=-822581.000 total time=   0.0s
# [CV 2/5; 23/25] START max_depth=10, min_samples_leaf=5..........................
# [CV 2/5; 23/25] END max_depth=10, min_samples_leaf=5;, score=-918555.000 total time=   0.0s
# [CV 3/5; 23/25] START max_depth=10, min_samples_leaf=5..........................
# [CV 3/5; 23/25] END max_depth=10, min_samples_leaf=5;, score=-902628.000 total time=   0.0s
# [CV 4/5; 23/25] START max_depth=10, min_samples_leaf=5..........................
# [CV 4/5; 23/25] END max_depth=10, min_samples_leaf=5;, score=-1041698.000 total time=   0.0s
# [CV 5/5; 23/25] START max_depth=10, min_samples_leaf=5..........................
# [CV 5/5; 23/25] END max_depth=10, min_samples_leaf=5;, score=-739656.000 total time=   0.0s
# [CV 1/5; 24/25] START max_depth=10, min_samples_leaf=7..........................
# [CV 1/5; 24/25] END max_depth=10, min_samples_leaf=7;, score=-883351.000 total time=   0.0s
# [CV 2/5; 24/25] START max_depth=10, min_samples_leaf=7..........................
# [CV 2/5; 24/25] END max_depth=10, min_samples_leaf=7;, score=-991275.000 total time=   0.0s
# [CV 3/5; 24/25] START max_depth=10, min_samples_leaf=7..........................
# [CV 3/5; 24/25] END max_depth=10, min_samples_leaf=7;, score=-960371.000 total time=   0.0s
# [CV 4/5; 24/25] START max_depth=10, min_samples_leaf=7..........................
# [CV 4/5; 24/25] END max_depth=10, min_samples_leaf=7;, score=-1061587.000 total time=   0.0s
# [CV 5/5; 24/25] START max_depth=10, min_samples_leaf=7..........................
# [CV 5/5; 24/25] END max_depth=10, min_samples_leaf=7;, score=-753648.000 total time=   0.0s
# [CV 1/5; 25/25] START max_depth=10, min_samples_leaf=10.........................
# [CV 1/5; 25/25] END max_depth=10, min_samples_leaf=10;, score=-824195.000 total time=   0.0s
# [CV 2/5; 25/25] START max_depth=10, min_samples_leaf=10.........................
# [CV 2/5; 25/25] END max_depth=10, min_samples_leaf=10;, score=-996421.000 total time=   0.0s
# [CV 3/5; 25/25] START max_depth=10, min_samples_leaf=10.........................
# [CV 3/5; 25/25] END max_depth=10, min_samples_leaf=10;, score=-1067404.000 total time=   0.0s
# [CV 4/5; 25/25] START max_depth=10, min_samples_leaf=10.........................
# [CV 4/5; 25/25] END max_depth=10, min_samples_leaf=10;, score=-866732.000 total time=   0.0s
# [CV 5/5; 25/25] START max_depth=10, min_samples_leaf=10.........................
# [CV 5/5; 25/25] END max_depth=10, min_samples_leaf=10;, score=-840983.000 total time=   0.0s
#
# Najlepsze hiperparametry: {'max_depth': 5, 'min_samples_leaf': 3}

# %%
prediction_tree = tree_model.predict(X_test)
prediction_tree = pd.Series(prediction_tree, index=y_test.index)
prediction_tree
# Out:
# 2020-01-01     195.750000
# 2020-01-02    1894.000000
# 2020-01-03    1894.000000
# 2020-01-04     203.852941
# 2020-01-05     203.852941
#                  ...
# 2020-05-16    3191.152941
# 2020-05-17    1650.627273
# 2020-05-18    2565.600000
# 2020-05-19    4135.896000
# 2020-05-20    5970.966667
# Length: 141, dtype: float64

# %%
plot_prediction_vs_true(yhat_list=[prediction_baseline, prediction_tree],
                        yhat_names=['Baseline', 'Tree'],
                        ytest=y_test)

# %%
model_evaluation(yhat=prediction_tree, ytest=y_test)
# Out:
# RMSE Test: 1132.7171793208827
# Pomniejszony zysk: 800310.0

# %%
forest = RandomForestRegressor(n_estimators=1000, random_state=2022)
params = {'max_depth': [2, 3, 5, 10],
          'min_samples_leaf': [3, 5, 10, 15]}
forest_gridsearch = GridSearchCV(forest,
                                 params,
                                 scoring=cost_scorer,
                                 cv=TimeSeriesSplit(n_splits=5),
                                 verbose=10,
                                 n_jobs=1)
forest_gridsearch.fit(X_train, y_train)
print('\nNajlepsze hiperparametry:', forest_gridsearch.best_params_)
forest_model = forest_gridsearch.best_estimator_
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5; 1/16] START max_depth=2, min_samples_leaf=3............................
# [CV 1/5; 1/16] END max_depth=2, min_samples_leaf=3;, score=-733461.000 total time=   0.6s
# [CV 2/5; 1/16] START max_depth=2, min_samples_leaf=3............................
# [CV 2/5; 1/16] END max_depth=2, min_samples_leaf=3;, score=-1206036.000 total time=   0.7s
# [CV 3/5; 1/16] START max_depth=2, min_samples_leaf=3............................
# [CV 3/5; 1/16] END max_depth=2, min_samples_leaf=3;, score=-883376.000 total time=   0.8s
# [CV 4/5; 1/16] START max_depth=2, min_samples_leaf=3............................
# [CV 4/5; 1/16] END max_depth=2, min_samples_leaf=3;, score=-1013672.000 total time=   0.9s
# [CV 5/5; 1/16] START max_depth=2, min_samples_leaf=3............................
# [CV 5/5; 1/16] END max_depth=2, min_samples_leaf=3;, score=-774505.000 total time=   1.0s
# [CV 1/5; 2/16] START max_depth=2, min_samples_leaf=5............................
# [CV 1/5; 2/16] END max_depth=2, min_samples_leaf=5;, score=-736469.000 total time=   0.6s
# [CV 2/5; 2/16] START max_depth=2, min_samples_leaf=5............................
# [CV 2/5; 2/16] END max_depth=2, min_samples_leaf=5;, score=-1206036.000 total time=   0.7s
# [CV 3/5; 2/16] START max_depth=2, min_samples_leaf=5............................
# [CV 3/5; 2/16] END max_depth=2, min_samples_leaf=5;, score=-883920.000 total time=   0.8s
# [CV 4/5; 2/16] START max_depth=2, min_samples_leaf=5............................
# [CV 4/5; 2/16] END max_depth=2, min_samples_leaf=5;, score=-1013521.000 total time=   0.9s
# [CV 5/5; 2/16] START max_depth=2, min_samples_leaf=5............................
# [CV 5/5; 2/16] END max_depth=2, min_samples_leaf=5;, score=-774505.000 total time=   1.0s
# [CV 1/5; 3/16] START max_depth=2, min_samples_leaf=10...........................
# [CV 1/5; 3/16] END max_depth=2, min_samples_leaf=10;, score=-739323.000 total time=   0.8s
# [CV 2/5; 3/16] START max_depth=2, min_samples_leaf=10...........................
# [CV 2/5; 3/16] END max_depth=2, min_samples_leaf=10;, score=-1205587.000 total time=   0.7s
# [CV 3/5; 3/16] START max_depth=2, min_samples_leaf=10...........................
# [CV 3/5; 3/16] END max_depth=2, min_samples_leaf=10;, score=-881514.000 total time=   0.8s
# [CV 4/5; 3/16] START max_depth=2, min_samples_leaf=10...........................
# [CV 4/5; 3/16] END max_depth=2, min_samples_leaf=10;, score=-1013712.000 total time=   0.9s
# [CV 5/5; 3/16] START max_depth=2, min_samples_leaf=10...........................
# [CV 5/5; 3/16] END max_depth=2, min_samples_leaf=10;, score=-774468.000 total time=   1.0s
# [CV 1/5; 4/16] START max_depth=2, min_samples_leaf=15...........................
# [CV 1/5; 4/16] END max_depth=2, min_samples_leaf=15;, score=-764374.000 total time=   0.6s
# [CV 2/5; 4/16] START max_depth=2, min_samples_leaf=15...........................
# [CV 2/5; 4/16] END max_depth=2, min_samples_leaf=15;, score=-1205310.000 total time=   0.7s
# [CV 3/5; 4/16] START max_depth=2, min_samples_leaf=15...........................
# [CV 3/5; 4/16] END max_depth=2, min_samples_leaf=15;, score=-869725.000 total time=   0.8s
# [CV 4/5; 4/16] START max_depth=2, min_samples_leaf=15...........................
# [CV 4/5; 4/16] END max_depth=2, min_samples_leaf=15;, score=-1013632.000 total time=   1.0s
# [CV 5/5; 4/16] START max_depth=2, min_samples_leaf=15...........................
# [CV 5/5; 4/16] END max_depth=2, min_samples_leaf=15;, score=-774468.000 total time=   1.0s
# [CV 1/5; 5/16] START max_depth=3, min_samples_leaf=3............................
# [CV 1/5; 5/16] END max_depth=3, min_samples_leaf=3;, score=-684994.000 total time=   0.7s
# [CV 2/5; 5/16] START max_depth=3, min_samples_leaf=3............................
# [CV 2/5; 5/16] END max_depth=3, min_samples_leaf=3;, score=-1095072.000 total time=   0.8s
# [CV 3/5; 5/16] START max_depth=3, min_samples_leaf=3............................
# [CV 3/5; 5/16] END max_depth=3, min_samples_leaf=3;, score=-833441.000 total time=   0.9s
# [CV 4/5; 5/16] START max_depth=3, min_samples_leaf=3............................
# [CV 4/5; 5/16] END max_depth=3, min_samples_leaf=3;, score=-954003.000 total time=   1.1s
# [CV 5/5; 5/16] START max_depth=3, min_samples_leaf=3............................
# [CV 5/5; 5/16] END max_depth=3, min_samples_leaf=3;, score=-700005.000 total time=   1.3s
# [CV 1/5; 6/16] START max_depth=3, min_samples_leaf=5............................
# [CV 1/5; 6/16] END max_depth=3, min_samples_leaf=5;, score=-700730.000 total time=   0.7s
# [CV 2/5; 6/16] START max_depth=3, min_samples_leaf=5............................
# [CV 2/5; 6/16] END max_depth=3, min_samples_leaf=5;, score=-1097215.000 total time=   0.8s
# [CV 3/5; 6/16] START max_depth=3, min_samples_leaf=5............................
# [CV 3/5; 6/16] END max_depth=3, min_samples_leaf=5;, score=-837992.000 total time=   1.0s
# [CV 4/5; 6/16] START max_depth=3, min_samples_leaf=5............................
# [CV 4/5; 6/16] END max_depth=3, min_samples_leaf=5;, score=-957589.000 total time=   1.1s
# [CV 5/5; 6/16] START max_depth=3, min_samples_leaf=5............................
# [CV 5/5; 6/16] END max_depth=3, min_samples_leaf=5;, score=-706571.000 total time=   1.2s
# [CV 1/5; 7/16] START max_depth=3, min_samples_leaf=10...........................
# [CV 1/5; 7/16] END max_depth=3, min_samples_leaf=10;, score=-698900.000 total time=   0.7s
# [CV 2/5; 7/16] START max_depth=3, min_samples_leaf=10...........................
# [CV 2/5; 7/16] END max_depth=3, min_samples_leaf=10;, score=-1090958.000 total time=   0.8s
# [CV 3/5; 7/16] START max_depth=3, min_samples_leaf=10...........................
# [CV 3/5; 7/16] END max_depth=3, min_samples_leaf=10;, score=-823535.000 total time=   1.0s
# [CV 4/5; 7/16] START max_depth=3, min_samples_leaf=10...........................
# [CV 4/5; 7/16] END max_depth=3, min_samples_leaf=10;, score=-967583.000 total time=   1.1s
# [CV 5/5; 7/16] START max_depth=3, min_samples_leaf=10...........................
# [CV 5/5; 7/16] END max_depth=3, min_samples_leaf=10;, score=-722983.000 total time=   1.5s
# [CV 1/5; 8/16] START max_depth=3, min_samples_leaf=15...........................
# [CV 1/5; 8/16] END max_depth=3, min_samples_leaf=15;, score=-734088.000 total time=   0.7s
# [CV 2/5; 8/16] START max_depth=3, min_samples_leaf=15...........................
# [CV 2/5; 8/16] END max_depth=3, min_samples_leaf=15;, score=-1085717.000 total time=   0.9s
# [CV 3/5; 8/16] START max_depth=3, min_samples_leaf=15...........................
# [CV 3/5; 8/16] END max_depth=3, min_samples_leaf=15;, score=-793783.000 total time=   1.1s
# [CV 4/5; 8/16] START max_depth=3, min_samples_leaf=15...........................
# [CV 4/5; 8/16] END max_depth=3, min_samples_leaf=15;, score=-962206.000 total time=   1.1s
# [CV 5/5; 8/16] START max_depth=3, min_samples_leaf=15...........................
# [CV 5/5; 8/16] END max_depth=3, min_samples_leaf=15;, score=-732199.000 total time=   1.3s
# [CV 1/5; 9/16] START max_depth=5, min_samples_leaf=3............................
# [CV 1/5; 9/16] END max_depth=5, min_samples_leaf=3;, score=-686075.000 total time=   0.7s
# [CV 2/5; 9/16] START max_depth=5, min_samples_leaf=3............................
# [CV 2/5; 9/16] END max_depth=5, min_samples_leaf=3;, score=-996517.000 total time=   1.0s
# [CV 3/5; 9/16] START max_depth=5, min_samples_leaf=3............................
# [CV 3/5; 9/16] END max_depth=5, min_samples_leaf=3;, score=-743207.000 total time=   1.2s
# [CV 4/5; 9/16] START max_depth=5, min_samples_leaf=3............................
# [CV 4/5; 9/16] END max_depth=5, min_samples_leaf=3;, score=-871990.000 total time=   1.4s
# [CV 5/5; 9/16] START max_depth=5, min_samples_leaf=3............................
# [CV 5/5; 9/16] END max_depth=5, min_samples_leaf=3;, score=-653258.000 total time=   1.7s
# [CV 1/5; 10/16] START max_depth=5, min_samples_leaf=5...........................
# [CV 1/5; 10/16] END max_depth=5, min_samples_leaf=5;, score=-696885.000 total time=   1.0s
# [CV 2/5; 10/16] START max_depth=5, min_samples_leaf=5...........................
# [CV 2/5; 10/16] END max_depth=5, min_samples_leaf=5;, score=-1012762.000 total time=   1.0s
# [CV 3/5; 10/16] START max_depth=5, min_samples_leaf=5...........................
# [CV 3/5; 10/16] END max_depth=5, min_samples_leaf=5;, score=-750510.000 total time=   1.2s
# [CV 4/5; 10/16] START max_depth=5, min_samples_leaf=5...........................
# [CV 4/5; 10/16] END max_depth=5, min_samples_leaf=5;, score=-882575.000 total time=   1.5s
# [CV 5/5; 10/16] START max_depth=5, min_samples_leaf=5...........................
# [CV 5/5; 10/16] END max_depth=5, min_samples_leaf=5;, score=-661987.000 total time=   1.7s
# [CV 1/5; 11/16] START max_depth=5, min_samples_leaf=10..........................
# [CV 1/5; 11/16] END max_depth=5, min_samples_leaf=10;, score=-686455.000 total time=   0.7s
# [CV 2/5; 11/16] START max_depth=5, min_samples_leaf=10..........................
# [CV 2/5; 11/16] END max_depth=5, min_samples_leaf=10;, score=-1022367.000 total time=   0.9s
# [CV 3/5; 11/16] START max_depth=5, min_samples_leaf=10..........................
# [CV 3/5; 11/16] END max_depth=5, min_samples_leaf=10;, score=-771191.000 total time=   1.2s
# [CV 4/5; 11/16] START max_depth=5, min_samples_leaf=10..........................
# [CV 4/5; 11/16] END max_depth=5, min_samples_leaf=10;, score=-909062.000 total time=   1.4s
# [CV 5/5; 11/16] START max_depth=5, min_samples_leaf=10..........................
# [CV 5/5; 11/16] END max_depth=5, min_samples_leaf=10;, score=-673373.000 total time=   2.2s
# [CV 1/5; 12/16] START max_depth=5, min_samples_leaf=15..........................
# [CV 1/5; 12/16] END max_depth=5, min_samples_leaf=15;, score=-719479.000 total time=   0.8s
# [CV 2/5; 12/16] START max_depth=5, min_samples_leaf=15..........................
# [CV 2/5; 12/16] END max_depth=5, min_samples_leaf=15;, score=-1039512.000 total time=   1.1s
# [CV 3/5; 12/16] START max_depth=5, min_samples_leaf=15..........................
# [CV 3/5; 12/16] END max_depth=5, min_samples_leaf=15;, score=-774092.000 total time=   1.2s
# [CV 4/5; 12/16] START max_depth=5, min_samples_leaf=15..........................
# [CV 4/5; 12/16] END max_depth=5, min_samples_leaf=15;, score=-904030.000 total time=   1.4s
# [CV 5/5; 12/16] START max_depth=5, min_samples_leaf=15..........................
# [CV 5/5; 12/16] END max_depth=5, min_samples_leaf=15;, score=-689077.000 total time=   1.6s
# [CV 1/5; 13/16] START max_depth=10, min_samples_leaf=3..........................
# [CV 1/5; 13/16] END max_depth=10, min_samples_leaf=3;, score=-688483.000 total time=   0.9s
# [CV 2/5; 13/16] START max_depth=10, min_samples_leaf=3..........................
# [CV 2/5; 13/16] END max_depth=10, min_samples_leaf=3;, score=-950859.000 total time=   1.2s
# [CV 3/5; 13/16] START max_depth=10, min_samples_leaf=3..........................
# [CV 3/5; 13/16] END max_depth=10, min_samples_leaf=3;, score=-724838.000 total time=   1.5s
# [CV 4/5; 13/16] START max_depth=10, min_samples_leaf=3..........................
# [CV 4/5; 13/16] END max_depth=10, min_samples_leaf=3;, score=-784605.000 total time=   1.8s
# [CV 5/5; 13/16] START max_depth=10, min_samples_leaf=3..........................
# [CV 5/5; 13/16] END max_depth=10, min_samples_leaf=3;, score=-617727.000 total time=   2.2s
# [CV 1/5; 14/16] START max_depth=10, min_samples_leaf=5..........................
# [CV 1/5; 14/16] END max_depth=10, min_samples_leaf=5;, score=-709520.000 total time=   0.8s
# [CV 2/5; 14/16] START max_depth=10, min_samples_leaf=5..........................
# [CV 2/5; 14/16] END max_depth=10, min_samples_leaf=5;, score=-989520.000 total time=   1.0s
# [CV 3/5; 14/16] START max_depth=10, min_samples_leaf=5..........................
# [CV 3/5; 14/16] END max_depth=10, min_samples_leaf=5;, score=-748896.000 total time=   1.4s
# [CV 4/5; 14/16] START max_depth=10, min_samples_leaf=5..........................
# [CV 4/5; 14/16] END max_depth=10, min_samples_leaf=5;, score=-810413.000 total time=   1.7s
# [CV 5/5; 14/16] START max_depth=10, min_samples_leaf=5..........................
# [CV 5/5; 14/16] END max_depth=10, min_samples_leaf=5;, score=-633047.000 total time=   2.1s
# [CV 1/5; 15/16] START max_depth=10, min_samples_leaf=10.........................
# [CV 1/5; 15/16] END max_depth=10, min_samples_leaf=10;, score=-690525.000 total time=   0.7s
# [CV 2/5; 15/16] START max_depth=10, min_samples_leaf=10.........................
# [CV 2/5; 15/16] END max_depth=10, min_samples_leaf=10;, score=-1017516.000 total time=   0.9s
# [CV 3/5; 15/16] START max_depth=10, min_samples_leaf=10.........................
# [CV 3/5; 15/16] END max_depth=10, min_samples_leaf=10;, score=-769667.000 total time=   1.2s
# [CV 4/5; 15/16] START max_depth=10, min_samples_leaf=10.........................
# [CV 4/5; 15/16] END max_depth=10, min_samples_leaf=10;, score=-868197.000 total time=   1.5s
# [CV 5/5; 15/16] START max_depth=10, min_samples_leaf=10.........................
# [CV 5/5; 15/16] END max_depth=10, min_samples_leaf=10;, score=-649456.000 total time=   1.8s
# [CV 1/5; 16/16] START max_depth=10, min_samples_leaf=15.........................
# [CV 1/5; 16/16] END max_depth=10, min_samples_leaf=15;, score=-719480.000 total time=   0.6s
# [CV 2/5; 16/16] START max_depth=10, min_samples_leaf=15.........................
# [CV 2/5; 16/16] END max_depth=10, min_samples_leaf=15;, score=-1038249.000 total time=   0.9s
# [CV 3/5; 16/16] START max_depth=10, min_samples_leaf=15.........................
# [CV 3/5; 16/16] END max_depth=10, min_samples_leaf=15;, score=-776656.000 total time=   1.1s
# [CV 4/5; 16/16] START max_depth=10, min_samples_leaf=15.........................
# [CV 4/5; 16/16] END max_depth=10, min_samples_leaf=15;, score=-875418.000 total time=   1.6s
# [CV 5/5; 16/16] START max_depth=10, min_samples_leaf=15.........................
# [CV 5/5; 16/16] END max_depth=10, min_samples_leaf=15;, score=-674264.000 total time=   1.8s
#
# Najlepsze hiperparametry: {'max_depth': 10, 'min_samples_leaf': 3}

# %%
prediction_forest = forest_model.predict(X_test)
prediction_forest = pd.Series(prediction_forest, index=y_test.index)
prediction_forest
# Out:
# 2020-01-01     488.298322
# 2020-01-02    1670.018316
# 2020-01-03    1691.620504
# 2020-01-04     203.250789
# 2020-01-05     193.312215
#                  ...
# 2020-05-16    3140.332836
# 2020-05-17    1711.691448
# 2020-05-18    4819.098673
# 2020-05-19    4856.101628
# 2020-05-20    5672.112924
# Length: 141, dtype: float64

# %%
plot_prediction_vs_true(yhat_list=[prediction_baseline, prediction_tree, prediction_forest],
                        yhat_names=['Baseline', 'Tree', 'Forest'],
                        ytest=y_test)

# %%
model_evaluation(yhat=prediction_forest, ytest=y_test)
# Out:
# RMSE Test: 867.535341130796
# Pomniejszony zysk: 663150.0

# %%
explainer = shap.TreeExplainer(forest_model)
shap_values = explainer.shap_values(X_test)
shap.summary_plot(shap_values, X_test)

# %%
joblib.dump(forest_model, 'forest_model.pkl')
# Out:
# ['forest_model.pkl']
